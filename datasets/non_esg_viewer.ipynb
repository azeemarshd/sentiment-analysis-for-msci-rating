# %%
import pandas as pd

# %%
df = pd.read_csv("./raw_data/esg_headlines_non-esg.csv")

# %%
df
# Out:
#                                                headline guardian_keywords  \
# 0     Save three times your salary before you’re 40 ...        ['others']
# 1     Barnier: UK will lose access to EU security da...        ['others']
# 2     Experience: I was married to an Islamic State ...        ['others']
# 3     Marriage may improve chances of surviving a he...        ['others']
# 4     The gifs that keep on giving: hubris, genius, ...        ['others']
# ...                                                 ...               ...
# 4495  EU campaign feuds may lead to no official Brex...        ['others']
# 4496    Philip Hammond: there will be no Brexit budget         ['others']
# 4497  Prisoner who killed himself 'told staff voices...        ['others']
# 4498  Tiko Tuskadze: from Georgia with a passionate ...        ['others']
# 4499        In grief, I have found unexpected comforts         ['others']
#
#      esg_category
# 0         non-esg
# 1         non-esg
# 2         non-esg
# ...
