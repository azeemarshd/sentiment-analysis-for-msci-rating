# %%
import pandas as pd
from transformers import CamembertTokenizer, CamembertForSequenceClassification
import torch
import string
from spacy.lang.fr.stop_words import STOP_WORDS as fr_stop

def cleanse_french_text(text):
    # Convert to lowercase
    text = text.lower()

    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))

    # Remove stopwords
    words = text.split()
    cleaned_words = [word for word in words if word not in fr_stop]
    cleaned_text = ' '.join(cleaned_words)

    return cleaned_text

# Load the tokenizer and model
tokenizer = CamembertTokenizer.from_pretrained("camembert-base")
model = CamembertForSequenceClassification.from_pretrained("camembert-base")

# Load your dataset
df = pd.read_csv('../data/esg_fr_classification.csv', encoding='utf-8', sep=',')
df = df.sample(frac=1, random_state=42).reset_index(drop=True)
df['text'] = df['text'].apply(cleanse_french_text)
df['label'] = df['esg_category'].factorize()[0] 


texts = df['text'].tolist()
labels = df['label'].tolist()
# Out:
# Some weights of the model checkpoint at camembert-base were not used when initializing CamembertForSequenceClassification: ['lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.dense.weight', 'roberta.pooler.dense.bias', 'lm_head.layer_norm.weight', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing CamembertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CamembertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of CamembertForSequenceClassification were not initialized from the model checkpoint at camembert-base and are newly initialized: ['classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight', 'classifier.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from transformers import CamembertTokenizer, CamembertForSequenceClassification
import torch
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import accuracy_score

from tqdm.auto import tqdm


# Split dataset into training and testing
train_texts, test_texts, train_labels, test_labels = train_test_split(texts, labels, test_size=0.2)

# Tokenize the test set
inputs = tokenizer(texts, padding=True, truncation=True, return_tensors="pt", max_length=512)


# Convert your input data into PyTorch tensors
input_ids = inputs['input_ids']
attention_mask = inputs['attention_mask']

# Create a TensorDataset
dataset = TensorDataset(input_ids, attention_mask)

# Create a DataLoader
data_loader = DataLoader(dataset, batch_size=32) 

# Load your model
model = CamembertForSequenceClassification.from_pretrained("camembert-base")

# Predict in batches
model.eval()  # Set the model to evaluation mode
predictions = []
for batch in tqdm(data_loader, desc="Making Predictions"):
    input_ids, attention_mask = batch

    with torch.no_grad():
        outputs = model(input_ids, attention_mask=attention_mask)
        batch_predictions = torch.argmax(outputs.logits, dim=-1)
        predictions.extend(batch_predictions.cpu().numpy())
# Out:
# Some weights of the model checkpoint at camembert-base were not used when initializing CamembertForSequenceClassification: ['lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.dense.weight', 'roberta.pooler.dense.bias', 'lm_head.layer_norm.weight', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing CamembertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CamembertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of CamembertForSequenceClassification were not initialized from the model checkpoint at camembert-base and are newly initialized: ['classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight', 'classifier.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Making Predictions:   0%|          | 0/531 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 38
#      35 input_ids, attention_mask = batch
#      37 with torch.no_grad():
# ---> 38     outputs = model(input_ids, attention_mask=attention_mask)
#      39     batch_predictions = torch.argmax(outputs.logits, dim=-1)
#      40     predictions.extend(batch_predictions.cpu().numpy())
#
# File d:\azeem\Documents\UNIGE\MSc CS\sentiment-analysis-for-msci-rating\env\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File d:\azeem\Documents\UNIGE\MSc CS\sentiment-analysis-for-msci-rating\env\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File d:\azeem\Documents\UNIGE\MSc CS\sentiment-analysis-for-msci-rating\env\Lib\site-packages\transformers\models\camembert\modeling_camembert.py:1086, in CamembertForSequenceClassification.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1078 r"""
#    1079 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#    1080     Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#    1081     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#    1082     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#    1083 """
#    1084 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1086 outputs = self.roberta(
#    1087     input_ids,
#    1088     attention_mask=attention_mask,
#    1089     token_type_ids=token_type_ids,
#    1090     position_ids=position_ids,
#    1091     head_mask=head_mask,
#    1092     inputs_embeds=inputs_embeds,
#    1093     output_attentions=output_attentions,
#    1094     output_hidden_states=output_hidden_states,
#    1095     return_dict=return_dict,
#    1096 )
#    1097 sequence_output = outputs[0]
#    1098 logits = self.classifier(sequence_output)
#
# File d:\azeem\Documents\UNIGE\MSc CS\sentiment-analysis-for-msci-rating\env\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File d:\azeem\Documents\UNIGE\MSc CS\sentiment-analysis-for-msci-rating\env\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File d:\azeem\Documents\UNIGE\MSc CS\sentiment-analysis-for-msci-rating\env\Lib\site-packages\transformers\models\camembert\modeling_camembert.py:904, in CamembertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     895 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     897 embedding_output = self.embeddings(
#     898     input_ids=input_ids,
#     899     position_ids=position_ids,
#    (...)
#     902     past_key_values_length=past_key_values_length,
#     903 )
# --> 904 encoder_outputs = self.encoder(
#     905     embedding_output,
#     906     attention_mask=extended_attention_mask,
#     907     head_mask=head_mask,
#     908     encoder_hidden_states=encoder_hidden_states,
#     909     encoder_attention_mask=encoder_extended_attention_mask,
#     910     past_key_values=past_key_values,
#     911     use_cache=use_cache,
#     912     output_attentions=output_attentions,
#     913     output_hidden_states=output_hidden_states,
#     914     return_dict=return_dict,
#     915 )
#     916 sequence_output = encoder_outputs[0]
#     917 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File d:\azeem\Documents\UNIGE\MSc CS\sentiment-analysis-for-msci-rating\env\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File d:\azeem\Documents\UNIGE\MSc CS\sentiment-analysis-for-msci-rating\env\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File d:\azeem\Documents\UNIGE\MSc CS\sentiment-analysis-for-msci-rating\env\Lib\site-packages\transformers\models\camembert\modeling_camembert.py:541, in CamembertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     532     layer_outputs = torch.utils.checkpoint.checkpoint(
#     533         create_custom_forward(layer_module),
#     534         hidden_states,
#    (...)
#     538         encoder_attention_mask,
#     539     )
#     540 else:
# --> 541     layer_outputs = layer_module(
#     542         hidden_states,
#     543         attention_mask,
#     544         layer_head_mask,
#     545         encoder_hidden_states,
#     546         encoder_attention_mask,
#     547         past_key_value,
#     548         output_attentions,
#     549     )
#     551 hidden_states = layer_outputs[0]
#     552 if use_cache:
#
# File d:\azeem\Documents\UNIGE\MSc CS\sentiment-analysis-for-msci-rating\env\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File d:\azeem\Documents\UNIGE\MSc CS\sentiment-analysis-for-msci-rating\env\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File d:\azeem\Documents\UNIGE\MSc CS\sentiment-analysis-for-msci-rating\env\Lib\site-packages\transformers\models\camembert\modeling_camembert.py:425, in CamembertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     413 def forward(
#     414     self,
#     415     hidden_states: torch.Tensor,
#    (...)
#     422 ) -> Tuple[torch.Tensor]:
#     423     # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     424     self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 425     self_attention_outputs = self.attention(
#     426         hidden_states,
#     427         attention_mask,
#     428         head_mask,
#     429         output_attentions=output_attentions,
#     430         past_key_value=self_attn_past_key_value,
#     431     )
#     432     attention_output = self_attention_outputs[0]
#     434     # if decoder, the last output is tuple of self-attn cache
#
# File d:\azeem\Documents\UNIGE\MSc CS\sentiment-analysis-for-msci-rating\env\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File d:\azeem\Documents\UNIGE\MSc CS\sentiment-analysis-for-msci-rating\env\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File d:\azeem\Documents\UNIGE\MSc CS\sentiment-analysis-for-msci-rating\env\Lib\site-packages\transformers\models\camembert\modeling_camembert.py:352, in CamembertAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     342 def forward(
#     343     self,
#     344     hidden_states: torch.Tensor,
#    (...)
#     350     output_attentions: Optional[bool] = False,
#     351 ) -> Tuple[torch.Tensor]:
# --> 352     self_outputs = self.self(
#     353         hidden_states,
#     354         attention_mask,
#     355         head_mask,
#     356         encoder_hidden_states,
#     357         encoder_attention_mask,
#     358         past_key_value,
#     359         output_attentions,
#     360     )
#     361     attention_output = self.output(self_outputs[0], hidden_states)
#     362     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# File d:\azeem\Documents\UNIGE\MSc CS\sentiment-analysis-for-msci-rating\env\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File d:\azeem\Documents\UNIGE\MSc CS\sentiment-analysis-for-msci-rating\env\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File d:\azeem\Documents\UNIGE\MSc CS\sentiment-analysis-for-msci-rating\env\Lib\site-packages\transformers\models\camembert\modeling_camembert.py:248, in CamembertSelfAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     245     past_key_value = (key_layer, value_layer)
#     247 # Take the dot product between "query" and "key" to get the raw attention scores.
# --> 248 attention_scores = torch.matmul(query_layer, key_layer.transpose(-1, -2))
#     250 if self.position_embedding_type == "relative_key" or self.position_embedding_type == "relative_key_query":
#     251     query_length, key_length = query_layer.shape[2], key_layer.shape[2]
#
# KeyboardInterrupt:
